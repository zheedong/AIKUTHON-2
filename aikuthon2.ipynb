# %% [markdown]
# ## 1. Install libraries

# %%
# !pip install transformers
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 1>:1                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py:99 in system                      │
# │                                                                                                  │
# │    96 │   if pip_warn:                                                                           │
# │    97 │     kwargs.update({'also_return_output': True})                                          │
# │    98 │                                                                                          │
# │ ❱  99 │   output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=pr   │
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# !pip install evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=0c823263dd1a2e058f18b4f63ed22fb0181c096e90b0cd7bd38b2bd19da2b0c0
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# ...

# %%
# !pip install accelerate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 5.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 2. Data preprocessing

# %%
import json
with open("/content/drive/MyDrive/train.json", "r") as f:
  data = json.load(f)

# %%
train = data[:20000]
val = data[20000:]

# %%
with open("/content/drive/MyDrive/test.json", "r") as f:
  test = json.load(f)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, get_scheduler, DataCollatorForSeq2Seq

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, get_scheduler, DataCollatorForSeq2Seq

tokenizer = AutoTokenizer.from_pretrained("eenzeenee/t5-small-korean-summarization")
model = AutoModelForSeq2SeqLM.from_pretrained("eenzeenee/t5-small-korean-summarization")

# %%
train_data = []
val_data = []
test_data = []

for d in train:
  document = d["document"]
  summary = d["summary"]
  train_data.append({
      "document": document,
      "summary": summary
  })
# idx = 0
for d in val:
  document = d["document"]
  summary = d["summary"]
  val_data.append({
      "document": document,
      "summary": summary
  })
  # idx += 1
  # if idx == 10:
  #   break

# idx = 0
for d in test:
  document = d["document"]
  test_data.append({
      "document": document,
  })
  # idx += 1
  # if idx == 10:
  #   break

# %%
len(train_data), len(val_data), len(test_data)
# Out:
# (20000, 2194, 2740)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("noahkim/KoT5_news_summarization")

model = AutoModelForSeq2SeqLM.from_pretrained("noahkim/KoT5_news_summarization")

# %%
def preprocess_function(examples):
    inputs = examples["document"]
    labels = examples["summary"]
    model_inputs = tokenizer(inputs, max_length=512, padding=False, truncation=True)
    model_inputs["labels"] = tokenizer(text_target=labels, max_length=512, padding=False, truncation=True).input_ids
    return model_inputs

def preprocess_function_test(examples):
    inputs = examples["document"]
    model_inputs = tokenizer(inputs, max_length=512, padding=False, truncation=True)
    return model_inputs

# %%
from datasets import Dataset

train_data = Dataset.from_list(train_data)
val_data = Dataset.from_list(val_data)
test_data = Dataset.from_list(test_data)

# %%
train_dataset_processed = train_data.map(
        preprocess_function,
        batched=True,
        num_proc=8,
        remove_columns=train_data.column_names,
        load_from_cache_file=False,
        desc="Running tokenizer on train dataset",
    )
# Out:
# Running tokenizer on train dataset (num_proc=8):   0%|          | 0/20000 [00:00<?, ? examples/s]

# %%
valid_dataset_processed = val_data.map(
        preprocess_function,
        batched=True,
        num_proc=None,
        remove_columns=train_data.column_names,
        load_from_cache_file=False,
        desc="Running tokenizer on valid dataset",
    )

test_dataset_processed = test_data.map(
        preprocess_function_test,
        batched=True,
        num_proc=None,
        remove_columns=test_data.column_names,
        load_from_cache_file=False,
        desc="Running tokenizer on test dataset",
    )
# Out:
# ...
# Running tokenizer on test dataset:   0%|          | 0/2740 [00:00<?, ? examples/s]

# %%
from torch.utils.data import DataLoader

data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    pad_to_multiple_of=None,
)
train_dataloader = DataLoader(train_dataset_processed, batch_size=1, shuffle=True, collate_fn=data_collator)
valid_dataloader = DataLoader(valid_dataset_processed, batch_size=1, collate_fn=data_collator)
test_dataloader = DataLoader(test_dataset_processed, batch_size=1, collate_fn=data_collator)

# %% [markdown]
# ## 3. Train/Validate model

# %%
import torch

no_decay = ["bias", "LayerNorm.weight", "layer_norm.weight"]
optimizer_grouped_parameters = [
        {
            "params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
        {
            "params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
            "weight_decay": 0.0,
        },
    ]
optimizer = torch.optim.AdamW(optimizer_grouped_parameters, lr=5e-5)

# %%
import math
from accelerate import Accelerator

accelerator = Accelerator()
model, optimizer, train_dataloader, valid_dataloader, test_dataloader = accelerator.prepare(
    model, optimizer, train_dataloader, valid_dataloader, test_dataloader
)
gradient_accumulation_steps = 1
num_train_epochs = 1
num_update_steps_per_epoch = math.ceil(len(train_dataloader) / gradient_accumulation_steps)
max_train_steps = num_train_epochs * num_update_steps_per_epoch
num_warmup_steps = 1
lr_scheduler = get_scheduler(
    name="linear",
    optimizer=optimizer,
    num_warmup_steps=num_warmup_steps * gradient_accumulation_steps,
    num_training_steps=max_train_steps * gradient_accumulation_steps
)

# %%
import nltk
nltk.download('punkt')
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(nltk.sent_tokenize(label)) for label in labels]

    return preds, labels

def postprocess_text_test(preds):
    preds = [pred.strip() for pred in preds]

    preds = ["\n".join(nltk.sent_tokenize(pred)) for pred in preds]

    return preds
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from tqdm.auto import tqdm
import torch
import numpy as np
from datasets import load_metric
rouge_score = load_metric("rouge")
# progress_bar = tqdm(range(1))

for epoch in tqdm(range(num_train_epochs)):
    model.train()
    
    # train 부분입니다! 학습 시에는 주석을 해제하고 진행해주세요!
    # for step, batch in tqdm(enumerate(train_dataloader), total=len(train_dataloader)):
    #     outputs = model(**batch)
    #     loss = outputs.loss
    #     accelerator.backward(loss)

    #     optimizer.step()
    #     lr_scheduler.step()
    #     optimizer.zero_grad()
    #     # progress_bar.update(1)

    model.eval()

    for step, batch in tqdm(enumerate(valid_dataloader), total=len(valid_dataloader)):
        with torch.no_grad():
            generated_tokens = accelerator.unwrap_model(model).generate(
                batch["input_ids"],
                attention_mask=batch["attention_mask"],
            )

            generated_tokens = accelerator.pad_across_processes(
                generated_tokens, dim=1, pad_index=tokenizer.pad_token_id
            )
            labels = batch["labels"]

            labels = accelerator.pad_across_processes(
                batch["labels"], dim=1, pad_index=tokenizer.pad_token_id
            )

            generated_tokens = accelerator.gather(generated_tokens).cpu().numpy()
            labels = accelerator.gather(labels).cpu().numpy()

            labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
            if isinstance(generated_tokens, tuple):
                generated_tokens = generated_tokens[0]
            decoded_preds = tokenizer.batch_decode(
                generated_tokens, skip_special_tokens=True
            )
            decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

            decoded_preds, decoded_labels = postprocess_text(
                decoded_preds, decoded_labels
            )

            rouge_score.add_batch(predictions=decoded_preds, references=decoded_labels)

    result = rouge_score.compute()
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    result = {k: round(v, 4) for k, v in result.items()}
    print(f"Epoch {epoch}:", result)
# Out:
# <ipython-input-27-6cdbcfd0c75f>:5: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge_score = load_metric("rouge")
# ...
#   0%|          | 0/10 [00:00<?, ?it/s]
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (128) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Epoch 0: {'rouge1': 19.3333, 'rouge2': 10.3571, 'rougeL': 18.6944, 'rougeLsum': 19.1111}

# %% [markdown]
# ## 4. Test model

# %%
from tqdm import tqdm

model.eval()
summary_results = []
for step, batch in tqdm(enumerate(test_dataloader), total=len(test_dataloader)):
    with torch.no_grad():
        generated_tokens = accelerator.unwrap_model(model).generate(
            batch["input_ids"],
            attention_mask=batch["attention_mask"],
        )

        generated_tokens = accelerator.pad_across_processes(
            generated_tokens, dim=1, pad_index=tokenizer.pad_token_id
        )

        generated_tokens = accelerator.gather(generated_tokens).cpu().numpy()
        if isinstance(generated_tokens, tuple):
            generated_tokens = generated_tokens[0]
        decoded_preds = tokenizer.batch_decode(
            generated_tokens, skip_special_tokens=True
        )
        decoded_preds = postprocess_text_test(
            decoded_preds
        )
        # print(f"Summary: {decoded_preds}")
        summary_results.append(decoded_preds)
# Out:
#   0%|          | 0/2740 [00:00<?, ?it/s]You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 100%|██████████| 2740/2740 [20:06<00:00,  2.27it/s]

# %% [markdown]
# ## 5. Submission

# %% [markdown]
# 테스트 도중 해당 부분에서 코랩이 터지는 경우가 있었습니다. 만약 터지게 되면, 이전까지의 학습기록이 모두 날아가기 때문에 해당 파트는 캐글 노트북이나 로컬 환경을 이용해주시면 감사하겠습니다. GPU를 따로 사용하지 않아도 되기 때문에 속도 상의 문제는 없을 것 같습니다!

# %%
from transformers import AutoTokenizer, AutoModel

fe_tokenizer = AutoTokenizer.from_pretrained("monologg/kobert")
fe_model = AutoModel.from_pretrained("monologg/kobert")

# %%
temp = {"temp": summary_results}
with open("/content/drive/MyDrive/test.json", "w") as f:
  json.dump(temp, f, indent="\t")

# %%
pooler_outputs = []
for s in tqdm(summary_results):
  input_ids = fe_tokenizer(s, return_tensors="pt").input_ids
  pooler_output = fe_model(input_ids).pooler_output.squeeze(0)
  pooler_outputs.append(pooler_output)
# Out:
#   1%|▏         | 36/2740 [00:05<07:17,  6.17it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 2>:4                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in _call_impl            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# ...

# %%
import pandas as pd
pooler_outputs = torch.stack(pooler_outputs)
row_id = [i for i in range(768*len(test))]
group_id = []
for i in range(len(test)):
  for _ in range(768):
    group_id.append(i)
pooler_outputs = pooler_outputs.reshape(-1)
pooler_outputs = pooler_outputs.detach().numpy()
pred = pd.DataFrame({"row_id": row_id, "val": pooler_outputs.T})
pred.set_index("row_id")
pred

# %%
pred.to_csv('/content/drive/MyDrive/aikuthon2-test/pred.csv', index=False)

# %%
from datasets import load_dataset

dataset = load_dataset("daekeun-ml/naver-news-summarization-ko")
# Out:
# ...
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/daekeun-ml___csv/daekeun-ml--naver-news-summarization-ko-884ccea06154613b/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
test = dataset["test"]

# %%
answers = []
idx = 0
for d in test:
  summary = d["summary"]
  answers.append(summary)
  idx += 1

# %%
from tqdm import tqdm
pooler_answers = []
for s in tqdm(answers):
  input_ids = fe_tokenizer(s, return_tensors="pt").input_ids
  pooler_output = fe_model(input_ids).pooler_output.squeeze(0)
  pooler_answers.append(pooler_output)
# Out:
#   9%|▉         | 244/2740 [01:06<11:20,  3.67it/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 3>:5                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1501 in _call_impl            │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# ...

# %%
import torch.nn as nn
cos = nn.CosineSimilarity(dim=0, eps=1e-6)
results = 0
num_samples = len(pooler_answers)
for p, a in tqdm(zip(pooler_outputs, pooler_answers)):
  results += cos(p, a)
results = results / num_samples
results
# Out:
# 0it [00:00, ?it/s]
# tensor(0.8647, grad_fn=<DivBackward0>)

# %%
import pandas as pd
pooler_outputs = torch.stack(pooler_outputs)
row_id = [i for i in range(7680)]
group_id = []
for i in range(10):
  for _ in range(768):
    group_id.append(i)
pooler_outputs = pooler_outputs.reshape(-1)
pooler_outputs = pooler_outputs.detach().numpy()
pred = pd.DataFrame({"row_id": row_id, "val": pooler_outputs.T})
pred.set_index("row_id")
pred
# Out:
#       row_id       val
# 0          0  0.055235
# 1          1  0.028717
# 2          2 -0.387299
# 3          3 -0.062755
# 4          4 -0.922336
# ...      ...       ...
# 7675    7675 -0.055151
# 7676    7676 -0.854180
# 7677    7677  0.107054
# 7678    7678  0.073762
# 7679    7679  0.000777
#
# [7680 rows x 2 columns]

# %%
pooler_answers = torch.stack(pooler_answers)
row_id = [i for i in range(768*len(test))]
group_id = []
for i in range(len(test)):
  for _ in range(768):
    group_id.append(i)
pooler_answers = pooler_answers.reshape(-1)
pooler_answers = pooler_answers.detach().numpy()
ans = pd.DataFrame({"row_id": row_id, "group_id": group_id, "val": pooler_answers.T})
ans.set_index("row_id")
ans
# Out:
#       row_id  group_id       val
# 0          0         0  0.066024
# 1          1         0 -0.009081
# 2          2         0 -0.277746
# 3          3         0 -0.088625
# 4          4         0 -0.795359
# ...      ...       ...       ...
# 7675    7675         9 -0.064470
# 7676    7676         9 -0.979446
# 7677    7677         9  0.077429
# 7678    7678         9  0.029194
# 7679    7679         9 -0.005724
#
# [7680 rows x 3 columns]

# %%
ans.to_csv('/content/drive/MyDrive/aikuthon2-test/ans.csv', index=False)
